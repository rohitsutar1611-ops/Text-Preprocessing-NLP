# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer

# %%
nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\ROHIT SAGAR
# [nltk_data]     SUTAR\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to C:\Users\ROHIT SAGAR
# [nltk_data]     SUTAR\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# [nltk_data] Downloading package stopwords to C:\Users\ROHIT SAGAR
# [nltk_data]     SUTAR\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\ROHIT SAGAR
# [nltk_data]     SUTAR\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to C:\Users\ROHIT SAGAR
# [nltk_data]     SUTAR\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
text = "You must be the change you wish to see in the world."

# %%
print("\nOriginal Text:")
print(text)
# Out:
# Original Text:
# You must be the change you wish to see in the world.

# %%
tokens = word_tokenize(text)
print("\nTokens:")
print(tokens)
# Out:
# Tokens:
# ['You', 'must', 'be', 'the', 'change', 'you', 'wish', 'to', 'see', 'in', 'the', 'world', '.']

# %%
stop_words = set(stopwords.words('english'))
filtered_tokens = [word for word in tokens if word.lower() not in stop_words]
print("\nAfter Stopword Removal:")
print(filtered_tokens)
# Out:
# After Stopword Removal:
# ['must', 'change', 'wish', 'see', 'world', '.']

# %%
stemmer = PorterStemmer()
stemmed_words = [stemmer.stem(word) for word in filtered_tokens]
print("\nAfter Stemming:")
print(stemmed_words)
# Out:
# After Stemming:
# ['must', 'chang', 'wish', 'see', 'world', '.']

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_words = [lemmatizer.lemmatize(word) for word in filtered_tokens]
print("\nAfter Lemmatization:")
print(lemmatized_words)
# Out:
# After Lemmatization:
# ['must', 'change', 'wish', 'see', 'world', '.']
